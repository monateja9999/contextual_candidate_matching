# %% [markdown]
# ### 1. IMPORT

# %%
import json
import torch
import numpy as np
import random
import pandas as pd
from transformers import (
    DPRContextEncoder,
    DPRQuestionEncoder,
    DPRContextEncoderTokenizer,
    DPRQuestionEncoderTokenizer,
)
import torch.nn.functional as F
import math
from rank_bm25 import BM25Okapi

# %% [markdown]
# ### 2. CHECK CUDA

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# ### 3. LOAD TEST DATA

# %%
with open("./data/test_data.json", "r") as f:
    test_data = json.load(f)

comparison_data = pd.DataFrame()

# %% [markdown]
# ### 4. DEFINE FUNCTIONS TO CALCULATE AP, RR, NDCG

# %% [markdown]
# #### 4.1 AVERAGE PRECISION(AP)

# %%
def calculate_average_precision(relevance_list):
    """
    Calculates Average Precision (AP) for a single query.
    :param relevance_list: List of relevance scores (0s and 1s) for a query.
    :return: Average Precision (AP) for that query.
    """
    relevant_count = 0
    precision_sum = 0
    for i, relevance in enumerate(relevance_list):
        if relevance == 1:
            relevant_count += 1
            precision_sum += relevant_count / (i + 1)
    
    if relevant_count == 0:
        return 0  # No relevant items, AP is 0
    return precision_sum / relevant_count

# %% [markdown]
# #### 4.2 AVERAGE PRECISION MODIFIED VERSION(AP-modified)

# %%
def calculate_modified_average_precision(relevance_list):
    """
    Calculates Modified Average Precision (AP) for a single query.
    :param relevance_list: List of relevance scores (0s and 1s) for a query.
    :return: Modified Average Precision (AP) for that query.

    Note:- This function imposes penality on irrelevant documents
    """
    count = 0
    precision_sum = 0
    for i, relevance in enumerate(relevance_list):
        if relevance == 1:
            count += 1
        precision_sum += count / (i + 1)
    
    if count == 0:
        return 0  # No relevant items, AP is 0
    return precision_sum / len(relevance_list)

# %% [markdown]
# #### 4.3 RECIPROCAL RANK(RR)

# %%
def calculate_reciprocal_rank(relevance_list):
    """
    Calculates Reciprocal rank for a single query.
    :param relevance_list: List of relevance scores (0s and 1s) for a query.
    :return: Reciprocal rank for that query.

    Note:- This function is based on the first relevant document retrieved
    """

    rec_rank = 0

    for i, relevance in enumerate(relevance_list):
        if relevance == 1:
            rec_rank = 1/(i+1)
            break
    
    return rec_rank

# %% [markdown]
# #### 4.4 NORMALIZED DISCOUNTED CUMULATIVE GAIN(NDCG)

# %%
def calculate_normalized_DCG_k(relevance_list,k):
    """
    Calculates Normalized Discounted Cumulative Gain at 'k' for a single query.
    :param relevance_list: List of relevance scores (0s and 1s) for a query.
    :return: Normalized Discounted Cumulative Gain at 'k' for that query.

    Note:- This function assigns higher imprtance to higher ranked documents.
    """

    IDCG_k = 0
    DCG_k = 0
    
    for i in range(k):
        if i == len(relevance_list):
            break
        IDCG_k += 1/(math.log(i+2,2))
        if relevance_list[i] == 1:
            DCG_k += 1/(math.log(i+2,2))

    if DCG_k == 0:
        return 0
    
    return DCG_k/IDCG_k

# %% [markdown]
# #### 4.5 SAMPLE RESULTS FOR ABOVE FUNCTIONS

# %%
relevance_list = [0,0,1,1,1]
relevance_list1 = [0,1,0,0,0]

print('AP relevance_list', round(calculate_average_precision(relevance_list), 4))
print('AP-modified relevance_list', round(calculate_modified_average_precision(relevance_list), 4))
print('RR relevance_list',round(calculate_reciprocal_rank(relevance_list), 4))
print('NDCG relevance_list', round(calculate_normalized_DCG_k(relevance_list,len(relevance_list)),4))

print()

print('AP relevance_list1', round(calculate_average_precision(relevance_list1), 4))
print('AP-modified relevance_list1', round(calculate_modified_average_precision(relevance_list1), 4))
print('RR relevance_list1',round(calculate_reciprocal_rank(relevance_list1), 4))
print('NDCG relevance_list1', round(calculate_normalized_DCG_k(relevance_list1,len(relevance_list1)),4))
# Out:
# AP relevance_list 0.4778
# AP-modified relevance_list 0.2867
# RR relevance_list 0.3333
# NDCG relevance_list 0.4469
#
# AP relevance_list1 0.5
# AP-modified relevance_list1 0.2567
# RR relevance_list1 0.5
# NDCG relevance_list1 0.214

# %% [markdown]
# ### 5. MODELS COMPARISON

# %% [markdown]
# #### 5.1 BM25

# %% [markdown]
# ##### 5.1.1 INITILAIZATIONS

# %%
correct_predictions = 0
positve_samples = 0
labels_list = []
accuracy_list = []

total_average_precision = 0
total_modified_average_precision = 0
total_reciprocal_rank = 0
total_normalized_DCG_k = 0

# %% [markdown]
# ##### 5.1.2 CALCULATE METRICS

# %%
for sample in test_data:
    label = sample["label"]
    job_description = sample["description"]
    pos_samples = sample["pos"]
    neg_samples = sample["neg"]
    all_samples = pos_samples + neg_samples
    random.shuffle(all_samples) 
	
	# Tokenize documents and prepare BM25
    tokenized_docs = [doc.split(" ") for doc in all_samples]
    bm25 = BM25Okapi(tokenized_docs)

	# Tokenize query and calculate similarity scores
    tokenized_query = job_description.split(" ")
    similarity_scores = bm25.get_scores(tokenized_query)

	# Retrieve top-5 documents
    _, indices = torch.topk(torch.from_numpy(similarity_scores), 5)
    # print('indices',indices)
	
    relevance_of_indices_retrieved = []
    relevant_passages = np.array(all_samples)[indices]
    num_correct = 0
    # print('relevant_passages',relevant_passages)
    for p in relevant_passages:
        if p in pos_samples:
            num_correct += 1
            relevance_of_indices_retrieved.append(1)
        else:
            relevance_of_indices_retrieved.append(0)
        
    correct_predictions += num_correct
    positve_samples += 5
    
    average_precision = calculate_average_precision(relevance_of_indices_retrieved)
    modified_average_precision = calculate_modified_average_precision(relevance_of_indices_retrieved)
    reciprocal_rank = calculate_reciprocal_rank(relevance_of_indices_retrieved)
    normalized_DCG_k = calculate_normalized_DCG_k(relevance_of_indices_retrieved,len(relevance_of_indices_retrieved))
    total_average_precision += average_precision
    total_modified_average_precision += modified_average_precision
    total_reciprocal_rank += reciprocal_rank
    total_normalized_DCG_k += normalized_DCG_k
    labels_list.append(label)
    accuracy_list.append(num_correct)
    
    print('relevance_of_indices_retrieved',relevance_of_indices_retrieved)
    print('Average Precision',round(average_precision, 4))
    print('Modified Average Precision', round(modified_average_precision, 4))
    print('Reciprocal Rank', round(reciprocal_rank, 4))
    print('Normalized DCG_k', round(normalized_DCG_k, 4))
    print(f"Accuracy ({label}): {num_correct}/{len(relevant_passages)}")
    print()

    # break

labels_list.append("Total")
accuracy_list.append(correct_predictions)
comparison_data["Label"] = labels_list
comparison_data["BM25"] = accuracy_list
total_average_precision = round(total_average_precision, 2)
total_modified_average_precision = round(total_modified_average_precision, 2)
total_reciprocal_rank = round(total_reciprocal_rank,2)
total_normalized_DCG_k = round(total_normalized_DCG_k, 2)

print(f"Mean Average Precision: {round(total_average_precision/len(test_data), 4)}")
print(f"Modified Mean Average Precision: {round(total_modified_average_precision/len(test_data), 4)}")
print(f"Mean Reciprocal Rank: {round(total_reciprocal_rank/len(test_data), 4)}")
print(f"Mean Normalized DCG_k: {round(total_normalized_DCG_k/len(test_data), 4)}")
print(f"Total accuracy: {correct_predictions}/{positve_samples}")
# Out:
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Security_Analyst): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Systems_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 0, 0, 0, 1]
# Average Precision 0.7
# Modified Average Precision 0.4967
# Reciprocal Rank 1.0
# Normalized DCG_k 0.4704
# Accuracy (Project_manager): 2/5
#
# relevance_of_indices_retrieved [1, 0, 0, 0, 1]
# Average Precision 0.7
# Modified Average Precision 0.4967
# Reciprocal Rank 1.0
# Normalized DCG_k 0.4704
# Accuracy (Database_Administrator): 2/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 1]
# Average Precision 0.8875
# Modified Average Precision 0.8433
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8304
# Accuracy (Software_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 0, 1, 0, 0]
# Average Precision 0.8333
# Modified Average Precision 0.6133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5087
# Accuracy (Front_End_Developer): 2/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 1]
# Average Precision 0.95
# Modified Average Precision 0.91
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8539
# Accuracy (Web_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Java_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 0, 1, 1, 0]
# Average Precision 0.8056
# Modified Average Precision 0.7033
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6548
# Accuracy (Network_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 1]
# Average Precision 0.95
# Modified Average Precision 0.91
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8539
# Accuracy (Python_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Security_Analyst): 3/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.7133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5531
# Accuracy (Systems_Administrator): 2/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Project_manager): 3/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.7133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5531
# Accuracy (Database_Administrator): 2/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 1]
# Average Precision 0.95
# Modified Average Precision 0.91
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8539
# Accuracy (Software_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Front_End_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.7133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5531
# Accuracy (Web_Developer): 2/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 1]
# Average Precision 0.95
# Modified Average Precision 0.91
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8539
# Accuracy (Java_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Network_Administrator): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 1]
# Average Precision 0.95
# Modified Average Precision 0.91
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8539
# Accuracy (Python_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 1]
# Average Precision 0.8667
# Modified Average Precision 0.7533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6844
# Accuracy (Security_Analyst): 3/5
#
# relevance_of_indices_retrieved [1, 0, 0, 1, 0]
# Average Precision 0.75
# Modified Average Precision 0.5467
# Reciprocal Rank 1.0
# Normalized DCG_k 0.4852
# Accuracy (Systems_Administrator): 2/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 1]
# Average Precision 0.8875
# Modified Average Precision 0.8433
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8304
# Accuracy (Project_manager): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Database_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 1]
# Average Precision 1.0
# Modified Average Precision 1.0
# Reciprocal Rank 1.0
# Normalized DCG_k 1.0
# Accuracy (Software_Developer): 5/5
#
# relevance_of_indices_retrieved [1, 0, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.4567
# Reciprocal Rank 1.0
# Normalized DCG_k 0.3392
# Accuracy (Front_End_Developer): 1/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Web_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 1]
# Average Precision 1.0
# Modified Average Precision 1.0
# Reciprocal Rank 1.0
# Normalized DCG_k 1.0
# Accuracy (Java_Developer): 5/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 0]
# Average Precision 0.9167
# Modified Average Precision 0.8033
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6992
# Accuracy (Network_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 0, 1, 1, 1]
# Average Precision 0.8042
# Modified Average Precision 0.7433
# Reciprocal Rank 1.0
# Normalized DCG_k 0.786
# Accuracy (Python_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Security_Analyst): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Systems_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Project_manager): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Database_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Software_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Front_End_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 1]
# Average Precision 0.8667
# Modified Average Precision 0.7533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6844
# Accuracy (Web_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 1]
# Average Precision 0.95
# Modified Average Precision 0.91
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8539
# Accuracy (Java_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 0]
# Average Precision 0.9167
# Modified Average Precision 0.8033
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6992
# Accuracy (Network_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Python_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Security_Analyst): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Systems_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 1]
# Average Precision 0.8667
# Modified Average Precision 0.7533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6844
# Accuracy (Project_manager): 3/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 0]
# Average Precision 0.9167
# Modified Average Precision 0.8033
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6992
# Accuracy (Database_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Software_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Front_End_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 0]
# Average Precision 0.9167
# Modified Average Precision 0.8033
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6992
# Accuracy (Web_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Java_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 0]
# Average Precision 0.9167
# Modified Average Precision 0.8033
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6992
# Accuracy (Network_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Python_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.7133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5531
# Accuracy (Security_Analyst): 2/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 0]
# Average Precision 0.9167
# Modified Average Precision 0.8033
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6992
# Accuracy (Systems_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Project_manager): 4/5
#
# relevance_of_indices_retrieved [1, 0, 0, 0, 1]
# Average Precision 0.7
# Modified Average Precision 0.4967
# Reciprocal Rank 1.0
# Normalized DCG_k 0.4704
# Accuracy (Database_Administrator): 2/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Software_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 1]
# Average Precision 0.95
# Modified Average Precision 0.91
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8539
# Accuracy (Front_End_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.7133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5531
# Accuracy (Web_Developer): 2/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Java_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 1]
# Average Precision 1.0
# Modified Average Precision 1.0
# Reciprocal Rank 1.0
# Normalized DCG_k 1.0
# Accuracy (Network_Administrator): 5/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.7133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5531
# Accuracy (Python_Developer): 2/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 1]
# Average Precision 1.0
# Modified Average Precision 1.0
# Reciprocal Rank 1.0
# Normalized DCG_k 1.0
# Accuracy (Security_Analyst): 5/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Systems_Administrator): 4/5
#
# relevance_of_indices_retrieved [1, 0, 1, 0, 1]
# Average Precision 0.7556
# Modified Average Precision 0.6533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6399
# Accuracy (Project_manager): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 1]
# Average Precision 0.95
# Modified Average Precision 0.91
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8539
# Accuracy (Database_Administrator): 4/5
#
# relevance_of_indices_retrieved [1, 0, 1, 0, 0]
# Average Precision 0.8333
# Modified Average Precision 0.6133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5087
# Accuracy (Software_Developer): 2/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 0]
# Average Precision 0.9167
# Modified Average Precision 0.8033
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6992
# Accuracy (Front_End_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 0, 1, 0, 0]
# Average Precision 0.8333
# Modified Average Precision 0.6133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5087
# Accuracy (Web_Developer): 2/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Java_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 0, 0, 1, 0]
# Average Precision 0.75
# Modified Average Precision 0.5467
# Reciprocal Rank 1.0
# Normalized DCG_k 0.4852
# Accuracy (Network_Administrator): 2/5
#
# relevance_of_indices_retrieved [1, 0, 1, 0, 0]
# Average Precision 0.8333
# Modified Average Precision 0.6133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5087
# Accuracy (Python_Developer): 2/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 1]
# Average Precision 0.95
# Modified Average Precision 0.91
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8539
# Accuracy (Security_Analyst): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Systems_Administrator): 4/5
#
# relevance_of_indices_retrieved [1, 0, 0, 1, 0]
# Average Precision 0.75
# Modified Average Precision 0.5467
# Reciprocal Rank 1.0
# Normalized DCG_k 0.4852
# Accuracy (Project_manager): 2/5
#
# relevance_of_indices_retrieved [1, 0, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.4567
# Reciprocal Rank 1.0
# Normalized DCG_k 0.3392
# Accuracy (Database_Administrator): 1/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Software_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 0, 0, 1, 1]
# Average Precision 0.7
# Modified Average Precision 0.5867
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6164
# Accuracy (Front_End_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 1]
# Average Precision 0.8875
# Modified Average Precision 0.8433
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8304
# Accuracy (Web_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 0]
# Average Precision 0.9167
# Modified Average Precision 0.8033
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6992
# Accuracy (Java_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Network_Administrator): 4/5
#
# relevance_of_indices_retrieved [1, 0, 1, 1, 0]
# Average Precision 0.8056
# Modified Average Precision 0.7033
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6548
# Accuracy (Python_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 0]
# Average Precision 0.9167
# Modified Average Precision 0.8033
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6992
# Accuracy (Security_Analyst): 3/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 1]
# Average Precision 0.8667
# Modified Average Precision 0.7533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6844
# Accuracy (Systems_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.7133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5531
# Accuracy (Project_manager): 2/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.7133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5531
# Accuracy (Database_Administrator): 2/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Software_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.7133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5531
# Accuracy (Front_End_Developer): 2/5
#
# relevance_of_indices_retrieved [1, 0, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.4567
# Reciprocal Rank 1.0
# Normalized DCG_k 0.3392
# Accuracy (Web_Developer): 1/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 1]
# Average Precision 0.95
# Modified Average Precision 0.91
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8539
# Accuracy (Java_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 1]
# Average Precision 0.8667
# Modified Average Precision 0.7533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6844
# Accuracy (Network_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Python_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Security_Analyst): 4/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 1]
# Average Precision 0.8667
# Modified Average Precision 0.7533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6844
# Accuracy (Systems_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 0, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.4567
# Reciprocal Rank 1.0
# Normalized DCG_k 0.3392
# Accuracy (Project_manager): 1/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Database_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 1]
# Average Precision 0.8875
# Modified Average Precision 0.8433
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8304
# Accuracy (Software_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 0, 1, 0, 1]
# Average Precision 0.7556
# Modified Average Precision 0.6533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6399
# Accuracy (Front_End_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 0]
# Average Precision 0.9167
# Modified Average Precision 0.8033
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6992
# Accuracy (Web_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 1]
# Average Precision 0.95
# Modified Average Precision 0.91
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8539
# Accuracy (Java_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 0, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.4567
# Reciprocal Rank 1.0
# Normalized DCG_k 0.3392
# Accuracy (Network_Administrator): 1/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Python_Developer): 4/5
#
# Mean Average Precision: 0.9368
# Modified Mean Average Precision: 0.8052
# Mean Reciprocal Rank: 1.0
# Mean Normalized DCG_k: 0.716
# Total accuracy: 315/500

# %% [markdown]
# #### 5.2 DPR BASE

# %% [markdown]
# ##### 5.2.1 INITIALIZATIONS

# %%
question_encoder = DPRQuestionEncoder.from_pretrained(
    "facebook/dpr-question_encoder-single-nq-base"
).to(device)

question_tokenizer = DPRQuestionEncoderTokenizer.from_pretrained(
    "facebook/dpr-question_encoder-single-nq-base"
)

context_encoder = DPRContextEncoder.from_pretrained(
    "facebook/dpr-ctx_encoder-single-nq-base"
).to(device)

context_tokenizer = DPRContextEncoderTokenizer.from_pretrained(
    "facebook/dpr-ctx_encoder-single-nq-base"
)

def encode(tokenizer, encoder, text):
    tokenized_output = tokenizer(
        text, return_tensors="pt", padding="max_length", max_length=512, truncation=True
    )
    input_ids = tokenized_output["input_ids"]
    attention_mask = tokenized_output["attention_mask"]

    return encoder(input_ids.to(device), attention_mask.to(device)).pooler_output

correct_predictions = 0
positve_samples = 0
accuracy_list = []

total_average_precision = 0
total_modified_average_precision = 0
total_reciprocal_rank = 0
total_normalized_DCG_k = 0
# Out:
# Some weights of the model checkpoint at facebook/dpr-question_encoder-single-nq-base were not used when initializing DPRQuestionEncoder: ['question_encoder.bert_model.pooler.dense.bias', 'question_encoder.bert_model.pooler.dense.weight']
# - This IS expected if you are initializing DPRQuestionEncoder from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DPRQuestionEncoder from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of the model checkpoint at facebook/dpr-ctx_encoder-single-nq-base were not used when initializing DPRContextEncoder: ['ctx_encoder.bert_model.pooler.dense.bias', 'ctx_encoder.bert_model.pooler.dense.weight']
# - This IS expected if you are initializing DPRContextEncoder from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DPRContextEncoder from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'DPRQuestionEncoderTokenizer'.
# The class this function is called from is 'DPRContextEncoderTokenizer'.

# %% [markdown]
# ##### 5.2.2 CALCULATE METRICS

# %%
for sample in test_data:
    label = sample["label"]
    job_description = sample["description"]
    pos_samples = sample["pos"]
    neg_samples = sample["neg"]
    all_samples = pos_samples + neg_samples
    random.shuffle(all_samples)

    # Encode the question and the context
    question_output = encode(question_tokenizer, question_encoder, job_description)
    context_output = encode(context_tokenizer, context_encoder, all_samples)
	
	# Find the cosine similarities of above encodings
    scores = F.cosine_similarity(question_output, context_output)
    _, indices = torch.topk(scores, 5)

    relevance_of_indices_retrieved = []

    relevant_passages = np.array(all_samples)[indices.cpu().numpy()]
    num_correct = 0
    for p in relevant_passages:
        if p in pos_samples:
            num_correct += 1
            relevance_of_indices_retrieved.append(1)
        else:
            relevance_of_indices_retrieved.append(0)

    correct_predictions += num_correct
    positve_samples += 5

    average_precision = calculate_average_precision(relevance_of_indices_retrieved)
    modified_average_precision = calculate_modified_average_precision(relevance_of_indices_retrieved)
    reciprocal_rank = calculate_reciprocal_rank(relevance_of_indices_retrieved)
    normalized_DCG_k = calculate_normalized_DCG_k(relevance_of_indices_retrieved, len(relevance_of_indices_retrieved))
    total_average_precision += average_precision
    total_modified_average_precision += modified_average_precision
    total_reciprocal_rank += reciprocal_rank
    total_normalized_DCG_k += normalized_DCG_k
    accuracy_list.append(num_correct)

    print('relevance_of_indices_retrieved',relevance_of_indices_retrieved)
    print('Average Precision',round(average_precision, 4))
    print('Modified Average Precision', round(modified_average_precision, 4))
    print('Reciprocal Rank', round(reciprocal_rank, 4))
    print('Normalized DCG_k', round(normalized_DCG_k, 4))
    print(f"Accuracy ({label}): {num_correct}/{len(relevant_passages)}")
    print()
accuracy_list.append(correct_predictions)
comparison_data["DPR Base"] = accuracy_list
total_average_precision = round(total_average_precision, 2)
total_modified_average_precision = round(total_modified_average_precision, 2)
total_reciprocal_rank = round(total_reciprocal_rank, 2)
total_normalized_DCG_k = round(total_normalized_DCG_k, 2)

print(f"Mean Average Precision: {round(total_average_precision/len(test_data), 4)}")
print(f"Modified Mean Average Precision: {round(total_modified_average_precision/len(test_data), 4)}")
print(f"Mean Reciprocal Rank: {round(total_reciprocal_rank/len(test_data), 4)}")
print(f"Mean Normalized DCG_k: {round(total_normalized_DCG_k/len(test_data), 4)}")
print(f"Total accuracy: {correct_predictions}/{positve_samples}")
# Out:
# relevance_of_indices_retrieved [0, 0, 1, 0, 1]
# Average Precision 0.3667
# Modified Average Precision 0.1967
# Reciprocal Rank 0.3333
# Normalized DCG_k 0.3008
# Accuracy (Security_Analyst): 2/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 0]
# Average Precision 0.9167
# Modified Average Precision 0.8033
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6992
# Accuracy (Systems_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 0]
# Average Precision 0.9167
# Modified Average Precision 0.8033
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6992
# Accuracy (Project_manager): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Database_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 1]
# Average Precision 0.8667
# Modified Average Precision 0.7533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6844
# Accuracy (Software_Developer): 3/5
#
# relevance_of_indices_retrieved [0, 1, 0, 0, 1]
# Average Precision 0.45
# Modified Average Precision 0.2967
# Reciprocal Rank 0.5
# Normalized DCG_k 0.3452
# Accuracy (Front_End_Developer): 2/5
#
# relevance_of_indices_retrieved [0, 0, 0, 0, 0]
# Average Precision 0
# Modified Average Precision 0
# Reciprocal Rank 0
# Normalized DCG_k 0
# Accuracy (Web_Developer): 0/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 1]
# Average Precision 0.8667
# Modified Average Precision 0.7533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6844
# Accuracy (Java_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 1]
# Average Precision 0.8667
# Modified Average Precision 0.7533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6844
# Accuracy (Network_Administrator): 3/5
#
# relevance_of_indices_retrieved [0, 1, 1, 0, 0]
# Average Precision 0.5833
# Modified Average Precision 0.4133
# Reciprocal Rank 0.5
# Normalized DCG_k 0.3836
# Accuracy (Python_Developer): 2/5
#
# relevance_of_indices_retrieved [0, 1, 0, 1, 1]
# Average Precision 0.5333
# Modified Average Precision 0.3867
# Reciprocal Rank 0.5
# Normalized DCG_k 0.4913
# Accuracy (Security_Analyst): 3/5
#
# relevance_of_indices_retrieved [0, 1, 1, 0, 1]
# Average Precision 0.5889
# Modified Average Precision 0.4533
# Reciprocal Rank 0.5
# Normalized DCG_k 0.5148
# Accuracy (Systems_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Project_manager): 3/5
#
# relevance_of_indices_retrieved [1, 0, 1, 0, 1]
# Average Precision 0.7556
# Modified Average Precision 0.6533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6399
# Accuracy (Database_Administrator): 3/5
#
# relevance_of_indices_retrieved [0, 0, 1, 1, 1]
# Average Precision 0.4778
# Modified Average Precision 0.2867
# Reciprocal Rank 0.3333
# Normalized DCG_k 0.4469
# Accuracy (Software_Developer): 3/5
#
# relevance_of_indices_retrieved [0, 1, 1, 0, 0]
# Average Precision 0.5833
# Modified Average Precision 0.4133
# Reciprocal Rank 0.5
# Normalized DCG_k 0.3836
# Accuracy (Front_End_Developer): 2/5
#
# relevance_of_indices_retrieved [0, 1, 0, 1, 1]
# Average Precision 0.5333
# Modified Average Precision 0.3867
# Reciprocal Rank 0.5
# Normalized DCG_k 0.4913
# Accuracy (Web_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 0, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.4567
# Reciprocal Rank 1.0
# Normalized DCG_k 0.3392
# Accuracy (Java_Developer): 1/5
#
# relevance_of_indices_retrieved [0, 1, 1, 1, 0]
# Average Precision 0.6389
# Modified Average Precision 0.5033
# Reciprocal Rank 0.5
# Normalized DCG_k 0.5296
# Accuracy (Network_Administrator): 3/5
#
# relevance_of_indices_retrieved [0, 1, 0, 1, 0]
# Average Precision 0.5
# Modified Average Precision 0.3467
# Reciprocal Rank 0.5
# Normalized DCG_k 0.3601
# Accuracy (Python_Developer): 2/5
#
# relevance_of_indices_retrieved [1, 0, 1, 1, 0]
# Average Precision 0.8056
# Modified Average Precision 0.7033
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6548
# Accuracy (Security_Analyst): 3/5
#
# relevance_of_indices_retrieved [1, 0, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.4567
# Reciprocal Rank 1.0
# Normalized DCG_k 0.3392
# Accuracy (Systems_Administrator): 1/5
#
# relevance_of_indices_retrieved [0, 1, 0, 0, 1]
# Average Precision 0.45
# Modified Average Precision 0.2967
# Reciprocal Rank 0.5
# Normalized DCG_k 0.3452
# Accuracy (Project_manager): 2/5
#
# relevance_of_indices_retrieved [1, 0, 1, 0, 1]
# Average Precision 0.7556
# Modified Average Precision 0.6533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6399
# Accuracy (Database_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 1]
# Average Precision 0.8667
# Modified Average Precision 0.7533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6844
# Accuracy (Software_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 0, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.4567
# Reciprocal Rank 1.0
# Normalized DCG_k 0.3392
# Accuracy (Front_End_Developer): 1/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.7133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5531
# Accuracy (Web_Developer): 2/5
#
# relevance_of_indices_retrieved [0, 0, 1, 0, 1]
# Average Precision 0.3667
# Modified Average Precision 0.1967
# Reciprocal Rank 0.3333
# Normalized DCG_k 0.3008
# Accuracy (Java_Developer): 2/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Network_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 0, 1, 0, 0]
# Average Precision 0.8333
# Modified Average Precision 0.6133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5087
# Accuracy (Python_Developer): 2/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 1]
# Average Precision 1.0
# Modified Average Precision 1.0
# Reciprocal Rank 1.0
# Normalized DCG_k 1.0
# Accuracy (Security_Analyst): 5/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 1]
# Average Precision 1.0
# Modified Average Precision 1.0
# Reciprocal Rank 1.0
# Normalized DCG_k 1.0
# Accuracy (Systems_Administrator): 5/5
#
# relevance_of_indices_retrieved [1, 0, 1, 1, 0]
# Average Precision 0.8056
# Modified Average Precision 0.7033
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6548
# Accuracy (Project_manager): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Database_Administrator): 4/5
#
# relevance_of_indices_retrieved [1, 0, 0, 1, 0]
# Average Precision 0.75
# Modified Average Precision 0.5467
# Reciprocal Rank 1.0
# Normalized DCG_k 0.4852
# Accuracy (Software_Developer): 2/5
#
# relevance_of_indices_retrieved [1, 0, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.4567
# Reciprocal Rank 1.0
# Normalized DCG_k 0.3392
# Accuracy (Front_End_Developer): 1/5
#
# relevance_of_indices_retrieved [0, 0, 1, 0, 0]
# Average Precision 0.3333
# Modified Average Precision 0.1567
# Reciprocal Rank 0.3333
# Normalized DCG_k 0.1696
# Accuracy (Web_Developer): 1/5
#
# relevance_of_indices_retrieved [0, 0, 0, 0, 0]
# Average Precision 0
# Modified Average Precision 0
# Reciprocal Rank 0
# Normalized DCG_k 0
# Accuracy (Java_Developer): 0/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Network_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 0, 1, 1, 0]
# Average Precision 0.8056
# Modified Average Precision 0.7033
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6548
# Accuracy (Python_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 0, 1, 0, 1]
# Average Precision 0.7556
# Modified Average Precision 0.6533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6399
# Accuracy (Security_Analyst): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Systems_Administrator): 3/5
#
# relevance_of_indices_retrieved [0, 1, 1, 0, 1]
# Average Precision 0.5889
# Modified Average Precision 0.4533
# Reciprocal Rank 0.5
# Normalized DCG_k 0.5148
# Accuracy (Project_manager): 3/5
#
# relevance_of_indices_retrieved [1, 0, 1, 0, 1]
# Average Precision 0.7556
# Modified Average Precision 0.6533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6399
# Accuracy (Database_Administrator): 3/5
#
# relevance_of_indices_retrieved [0, 0, 1, 1, 0]
# Average Precision 0.4167
# Modified Average Precision 0.2467
# Reciprocal Rank 0.3333
# Normalized DCG_k 0.3156
# Accuracy (Software_Developer): 2/5
#
# relevance_of_indices_retrieved [0, 1, 1, 0, 0]
# Average Precision 0.5833
# Modified Average Precision 0.4133
# Reciprocal Rank 0.5
# Normalized DCG_k 0.3836
# Accuracy (Front_End_Developer): 2/5
#
# relevance_of_indices_retrieved [1, 0, 0, 0, 1]
# Average Precision 0.7
# Modified Average Precision 0.4967
# Reciprocal Rank 1.0
# Normalized DCG_k 0.4704
# Accuracy (Web_Developer): 2/5
#
# relevance_of_indices_retrieved [0, 0, 0, 0, 0]
# Average Precision 0
# Modified Average Precision 0
# Reciprocal Rank 0
# Normalized DCG_k 0
# Accuracy (Java_Developer): 0/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Network_Administrator): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 1]
# Average Precision 0.95
# Modified Average Precision 0.91
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8539
# Accuracy (Python_Developer): 4/5
#
# relevance_of_indices_retrieved [0, 1, 0, 0, 1]
# Average Precision 0.45
# Modified Average Precision 0.2967
# Reciprocal Rank 0.5
# Normalized DCG_k 0.3452
# Accuracy (Security_Analyst): 2/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Systems_Administrator): 4/5
#
# relevance_of_indices_retrieved [0, 1, 0, 0, 0]
# Average Precision 0.5
# Modified Average Precision 0.2567
# Reciprocal Rank 0.5
# Normalized DCG_k 0.214
# Accuracy (Project_manager): 1/5
#
# relevance_of_indices_retrieved [1, 0, 0, 1, 0]
# Average Precision 0.75
# Modified Average Precision 0.5467
# Reciprocal Rank 1.0
# Normalized DCG_k 0.4852
# Accuracy (Database_Administrator): 2/5
#
# relevance_of_indices_retrieved [0, 0, 0, 0, 1]
# Average Precision 0.2
# Modified Average Precision 0.04
# Reciprocal Rank 0.2
# Normalized DCG_k 0.1312
# Accuracy (Software_Developer): 1/5
#
# relevance_of_indices_retrieved [0, 0, 0, 0, 1]
# Average Precision 0.2
# Modified Average Precision 0.04
# Reciprocal Rank 0.2
# Normalized DCG_k 0.1312
# Accuracy (Front_End_Developer): 1/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 1]
# Average Precision 0.8667
# Modified Average Precision 0.7533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6844
# Accuracy (Web_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 0, 0, 1, 1]
# Average Precision 0.7
# Modified Average Precision 0.5867
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6164
# Accuracy (Java_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Network_Administrator): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Python_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Security_Analyst): 4/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 1]
# Average Precision 0.8667
# Modified Average Precision 0.7533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6844
# Accuracy (Systems_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 0, 1, 0, 0]
# Average Precision 0.8333
# Modified Average Precision 0.6133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5087
# Accuracy (Project_manager): 2/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Database_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 0, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.4567
# Reciprocal Rank 1.0
# Normalized DCG_k 0.3392
# Accuracy (Software_Developer): 1/5
#
# relevance_of_indices_retrieved [1, 0, 1, 0, 0]
# Average Precision 0.8333
# Modified Average Precision 0.6133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5087
# Accuracy (Front_End_Developer): 2/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.7133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5531
# Accuracy (Web_Developer): 2/5
#
# relevance_of_indices_retrieved [0, 0, 0, 0, 1]
# Average Precision 0.2
# Modified Average Precision 0.04
# Reciprocal Rank 0.2
# Normalized DCG_k 0.1312
# Accuracy (Java_Developer): 1/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Network_Administrator): 3/5
#
# relevance_of_indices_retrieved [0, 0, 1, 0, 1]
# Average Precision 0.3667
# Modified Average Precision 0.1967
# Reciprocal Rank 0.3333
# Normalized DCG_k 0.3008
# Accuracy (Python_Developer): 2/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 1]
# Average Precision 1.0
# Modified Average Precision 1.0
# Reciprocal Rank 1.0
# Normalized DCG_k 1.0
# Accuracy (Security_Analyst): 5/5
#
# relevance_of_indices_retrieved [0, 0, 1, 1, 0]
# Average Precision 0.4167
# Modified Average Precision 0.2467
# Reciprocal Rank 0.3333
# Normalized DCG_k 0.3156
# Accuracy (Systems_Administrator): 2/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.7133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5531
# Accuracy (Project_manager): 2/5
#
# relevance_of_indices_retrieved [1, 0, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.4567
# Reciprocal Rank 1.0
# Normalized DCG_k 0.3392
# Accuracy (Database_Administrator): 1/5
#
# relevance_of_indices_retrieved [1, 0, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.4567
# Reciprocal Rank 1.0
# Normalized DCG_k 0.3392
# Accuracy (Software_Developer): 1/5
#
# relevance_of_indices_retrieved [0, 0, 1, 0, 0]
# Average Precision 0.3333
# Modified Average Precision 0.1567
# Reciprocal Rank 0.3333
# Normalized DCG_k 0.1696
# Accuracy (Front_End_Developer): 1/5
#
# relevance_of_indices_retrieved [0, 0, 0, 0, 1]
# Average Precision 0.2
# Modified Average Precision 0.04
# Reciprocal Rank 0.2
# Normalized DCG_k 0.1312
# Accuracy (Web_Developer): 1/5
#
# relevance_of_indices_retrieved [1, 0, 0, 1, 1]
# Average Precision 0.7
# Modified Average Precision 0.5867
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6164
# Accuracy (Java_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 1]
# Average Precision 1.0
# Modified Average Precision 1.0
# Reciprocal Rank 1.0
# Normalized DCG_k 1.0
# Accuracy (Network_Administrator): 5/5
#
# relevance_of_indices_retrieved [1, 0, 1, 0, 1]
# Average Precision 0.7556
# Modified Average Precision 0.6533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6399
# Accuracy (Python_Developer): 3/5
#
# relevance_of_indices_retrieved [0, 0, 0, 1, 1]
# Average Precision 0.325
# Modified Average Precision 0.13
# Reciprocal Rank 0.25
# Normalized DCG_k 0.2773
# Accuracy (Security_Analyst): 2/5
#
# relevance_of_indices_retrieved [1, 0, 1, 0, 1]
# Average Precision 0.7556
# Modified Average Precision 0.6533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6399
# Accuracy (Systems_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 0, 1, 1, 0]
# Average Precision 0.8056
# Modified Average Precision 0.7033
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6548
# Accuracy (Project_manager): 3/5
#
# relevance_of_indices_retrieved [1, 0, 0, 1, 1]
# Average Precision 0.7
# Modified Average Precision 0.5867
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6164
# Accuracy (Database_Administrator): 3/5
#
# relevance_of_indices_retrieved [0, 0, 0, 1, 0]
# Average Precision 0.25
# Modified Average Precision 0.09
# Reciprocal Rank 0.25
# Normalized DCG_k 0.1461
# Accuracy (Software_Developer): 1/5
#
# relevance_of_indices_retrieved [0, 0, 0, 0, 0]
# Average Precision 0
# Modified Average Precision 0
# Reciprocal Rank 0
# Normalized DCG_k 0
# Accuracy (Front_End_Developer): 0/5
#
# relevance_of_indices_retrieved [0, 1, 1, 0, 1]
# Average Precision 0.5889
# Modified Average Precision 0.4533
# Reciprocal Rank 0.5
# Normalized DCG_k 0.5148
# Accuracy (Web_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 0, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.4567
# Reciprocal Rank 1.0
# Normalized DCG_k 0.3392
# Accuracy (Java_Developer): 1/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 0]
# Average Precision 0.9167
# Modified Average Precision 0.8033
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6992
# Accuracy (Network_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 0, 1, 0, 1]
# Average Precision 0.7556
# Modified Average Precision 0.6533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6399
# Accuracy (Python_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 1]
# Average Precision 0.8875
# Modified Average Precision 0.8433
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8304
# Accuracy (Security_Analyst): 4/5
#
# relevance_of_indices_retrieved [0, 1, 0, 1, 0]
# Average Precision 0.5
# Modified Average Precision 0.3467
# Reciprocal Rank 0.5
# Normalized DCG_k 0.3601
# Accuracy (Systems_Administrator): 2/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Project_manager): 3/5
#
# relevance_of_indices_retrieved [1, 0, 1, 0, 0]
# Average Precision 0.8333
# Modified Average Precision 0.6133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5087
# Accuracy (Database_Administrator): 2/5
#
# relevance_of_indices_retrieved [0, 1, 1, 0, 0]
# Average Precision 0.5833
# Modified Average Precision 0.4133
# Reciprocal Rank 0.5
# Normalized DCG_k 0.3836
# Accuracy (Software_Developer): 2/5
#
# relevance_of_indices_retrieved [0, 1, 1, 0, 1]
# Average Precision 0.5889
# Modified Average Precision 0.4533
# Reciprocal Rank 0.5
# Normalized DCG_k 0.5148
# Accuracy (Front_End_Developer): 3/5
#
# relevance_of_indices_retrieved [0, 1, 0, 0, 0]
# Average Precision 0.5
# Modified Average Precision 0.2567
# Reciprocal Rank 0.5
# Normalized DCG_k 0.214
# Accuracy (Web_Developer): 1/5
#
# relevance_of_indices_retrieved [0, 1, 0, 0, 0]
# Average Precision 0.5
# Modified Average Precision 0.2567
# Reciprocal Rank 0.5
# Normalized DCG_k 0.214
# Accuracy (Java_Developer): 1/5
#
# relevance_of_indices_retrieved [0, 1, 1, 1, 1]
# Average Precision 0.6792
# Modified Average Precision 0.5433
# Reciprocal Rank 0.5
# Normalized DCG_k 0.6608
# Accuracy (Network_Administrator): 4/5
#
# relevance_of_indices_retrieved [1, 0, 0, 0, 1]
# Average Precision 0.7
# Modified Average Precision 0.4967
# Reciprocal Rank 1.0
# Normalized DCG_k 0.4704
# Accuracy (Python_Developer): 2/5
#
# Mean Average Precision: 0.7101
# Modified Mean Average Precision: 0.5459
# Mean Reciprocal Rank: 0.7597
# Mean Normalized DCG_k: 0.5158
# Total accuracy: 243/500

# %% [markdown]
# #### 5.3 DPR FT(BATCH SIZE 16)

# %% [markdown]
# ##### 5.3.1 INITIALIZATIONS

# %%
question_encoder = DPRQuestionEncoder.from_pretrained(
    "./models_16/finetune_question_encoder"
).to(device)
context_encoder = DPRContextEncoder.from_pretrained(
    "./models_16/finetune_context_encoder"
).to(device)

correct_predictions = 0
positve_samples = 0
accuracy_list = []

total_average_precision = 0
total_modified_average_precision = 0
total_reciprocal_rank = 0
total_normalized_DCG_k = 0

# %% [markdown]
# ##### 5.3.2 CALCULATE METRICS

# %%
for sample in test_data:
    label = sample["label"]
    job_description = sample["description"]
    pos_samples = sample["pos"]
    neg_samples = sample["neg"]
    all_samples = pos_samples + neg_samples
    random.shuffle(all_samples)

	#encoded the job description and resumes
    question_output = encode(question_tokenizer, question_encoder, job_description)
    context_output = encode(context_tokenizer, context_encoder, all_samples)
	
	#compute similiarities of above encodings
    scores = F.cosine_similarity(question_output, context_output)
    _, indices = torch.topk(scores, 5)

    # print('indices',indices)
    relevance_of_indices_retrieved = []

    relevant_passages = np.array(all_samples)[indices.cpu().numpy()]
    num_correct = 0
    for p in relevant_passages:
        if p in pos_samples:
            num_correct += 1
            relevance_of_indices_retrieved.append(1)
        else:
            relevance_of_indices_retrieved.append(0)


    correct_predictions += num_correct
    positve_samples += 5

    average_precision = calculate_average_precision(relevance_of_indices_retrieved)
    modified_average_precision = calculate_modified_average_precision(relevance_of_indices_retrieved)
    reciprocal_rank = calculate_reciprocal_rank(relevance_of_indices_retrieved)
    normalized_DCG_k = calculate_normalized_DCG_k(relevance_of_indices_retrieved, len(relevance_of_indices_retrieved))
    total_average_precision += average_precision
    total_modified_average_precision += modified_average_precision
    total_reciprocal_rank += reciprocal_rank
    total_normalized_DCG_k += normalized_DCG_k

    accuracy_list.append(num_correct)
    print('relevance_of_indices_retrieved',relevance_of_indices_retrieved) 
    print('Average Precision',round(average_precision, 4))
    print('Modified Average Precision', round(modified_average_precision, 4))
    print('Reciprocal Rank',round(reciprocal_rank,4))
    print('Normalized DCG_k',round(normalized_DCG_k,4))
    print(f"Accuracy ({label}): {num_correct}/{len(relevant_passages)}")
    print()

accuracy_list.append(correct_predictions)
comparison_data["DPR FT2(16)"] = accuracy_list

total_average_precision = round(total_average_precision, 2)
total_modified_average_precision = round(total_modified_average_precision, 2)
total_reciprocal_rank = round(total_reciprocal_rank, 2)
total_normalized_DCG_k = round(total_normalized_DCG_k, 2)

print(f"Mean Average Precision: {round(total_average_precision/len(test_data), 4)}")
print(f"Modified Mean Average Precision: {round(total_modified_average_precision/len(test_data), 4)}")
print(f"Mean Reciprocal Rank: {round(total_reciprocal_rank/len(test_data), 4)}")
print(f"Mean Normalized DGC_k: {round(total_normalized_DCG_k/len(test_data), 4)}")
print(f"Total accuracy: {correct_predictions}/{positve_samples}")
# Out:
# relevance_of_indices_retrieved [0, 1, 1, 0, 1]
# Average Precision 0.5889
# Modified Average Precision 0.4533
# Reciprocal Rank 0.5
# Normalized DCG_k 0.5148
# Accuracy (Security_Analyst): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Systems_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 1]
# Average Precision 0.95
# Modified Average Precision 0.91
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8539
# Accuracy (Project_manager): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 1]
# Average Precision 1.0
# Modified Average Precision 1.0
# Reciprocal Rank 1.0
# Normalized DCG_k 1.0
# Accuracy (Database_Administrator): 5/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Software_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.7133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5531
# Accuracy (Front_End_Developer): 2/5
#
# relevance_of_indices_retrieved [1, 0, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.4567
# Reciprocal Rank 1.0
# Normalized DCG_k 0.3392
# Accuracy (Web_Developer): 1/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Java_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Network_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 0, 0, 1, 0]
# Average Precision 0.75
# Modified Average Precision 0.5467
# Reciprocal Rank 1.0
# Normalized DCG_k 0.4852
# Accuracy (Python_Developer): 2/5
#
# relevance_of_indices_retrieved [0, 1, 1, 1, 0]
# Average Precision 0.6389
# Modified Average Precision 0.5033
# Reciprocal Rank 0.5
# Normalized DCG_k 0.5296
# Accuracy (Security_Analyst): 3/5
#
# relevance_of_indices_retrieved [1, 0, 1, 1, 0]
# Average Precision 0.8056
# Modified Average Precision 0.7033
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6548
# Accuracy (Systems_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 0]
# Average Precision 0.9167
# Modified Average Precision 0.8033
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6992
# Accuracy (Project_manager): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Database_Administrator): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Software_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 1]
# Average Precision 0.95
# Modified Average Precision 0.91
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8539
# Accuracy (Front_End_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 1]
# Average Precision 0.8667
# Modified Average Precision 0.7533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6844
# Accuracy (Web_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 0, 0, 0, 1]
# Average Precision 0.7
# Modified Average Precision 0.4967
# Reciprocal Rank 1.0
# Normalized DCG_k 0.4704
# Accuracy (Java_Developer): 2/5
#
# relevance_of_indices_retrieved [1, 0, 0, 1, 0]
# Average Precision 0.75
# Modified Average Precision 0.5467
# Reciprocal Rank 1.0
# Normalized DCG_k 0.4852
# Accuracy (Network_Administrator): 2/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 1]
# Average Precision 0.95
# Modified Average Precision 0.91
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8539
# Accuracy (Python_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 0, 1, 1, 1]
# Average Precision 0.8042
# Modified Average Precision 0.7433
# Reciprocal Rank 1.0
# Normalized DCG_k 0.786
# Accuracy (Security_Analyst): 4/5
#
# relevance_of_indices_retrieved [1, 0, 1, 0, 0]
# Average Precision 0.8333
# Modified Average Precision 0.6133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5087
# Accuracy (Systems_Administrator): 2/5
#
# relevance_of_indices_retrieved [1, 0, 1, 1, 0]
# Average Precision 0.8056
# Modified Average Precision 0.7033
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6548
# Accuracy (Project_manager): 3/5
#
# relevance_of_indices_retrieved [0, 1, 0, 0, 1]
# Average Precision 0.45
# Modified Average Precision 0.2967
# Reciprocal Rank 0.5
# Normalized DCG_k 0.3452
# Accuracy (Database_Administrator): 2/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Software_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 0, 1, 0, 0]
# Average Precision 0.8333
# Modified Average Precision 0.6133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5087
# Accuracy (Front_End_Developer): 2/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 1]
# Average Precision 0.8667
# Modified Average Precision 0.7533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6844
# Accuracy (Web_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 0]
# Average Precision 0.9167
# Modified Average Precision 0.8033
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6992
# Accuracy (Java_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 1]
# Average Precision 0.8875
# Modified Average Precision 0.8433
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8304
# Accuracy (Network_Administrator): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Python_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 1]
# Average Precision 1.0
# Modified Average Precision 1.0
# Reciprocal Rank 1.0
# Normalized DCG_k 1.0
# Accuracy (Security_Analyst): 5/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Systems_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Project_manager): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Database_Administrator): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Software_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 0, 1, 0, 1]
# Average Precision 0.7556
# Modified Average Precision 0.6533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6399
# Accuracy (Front_End_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 0, 0, 0, 1]
# Average Precision 0.7
# Modified Average Precision 0.4967
# Reciprocal Rank 1.0
# Normalized DCG_k 0.4704
# Accuracy (Web_Developer): 2/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 1]
# Average Precision 0.8875
# Modified Average Precision 0.8433
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8304
# Accuracy (Java_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Network_Administrator): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 1]
# Average Precision 0.95
# Modified Average Precision 0.91
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8539
# Accuracy (Python_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 0, 1, 0, 0]
# Average Precision 0.8333
# Modified Average Precision 0.6133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5087
# Accuracy (Security_Analyst): 2/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 1]
# Average Precision 0.8875
# Modified Average Precision 0.8433
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8304
# Accuracy (Systems_Administrator): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Project_manager): 3/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 1]
# Average Precision 0.8667
# Modified Average Precision 0.7533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6844
# Accuracy (Database_Administrator): 3/5
#
# relevance_of_indices_retrieved [0, 1, 1, 1, 1]
# Average Precision 0.6792
# Modified Average Precision 0.5433
# Reciprocal Rank 0.5
# Normalized DCG_k 0.6608
# Accuracy (Software_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Front_End_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 0, 1, 0, 1]
# Average Precision 0.7556
# Modified Average Precision 0.6533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6399
# Accuracy (Web_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 0, 1, 1, 0]
# Average Precision 0.8056
# Modified Average Precision 0.7033
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6548
# Accuracy (Java_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 1]
# Average Precision 1.0
# Modified Average Precision 1.0
# Reciprocal Rank 1.0
# Normalized DCG_k 1.0
# Accuracy (Network_Administrator): 5/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Python_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 0]
# Average Precision 0.9167
# Modified Average Precision 0.8033
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6992
# Accuracy (Security_Analyst): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Systems_Administrator): 4/5
#
# relevance_of_indices_retrieved [1, 0, 0, 0, 1]
# Average Precision 0.7
# Modified Average Precision 0.4967
# Reciprocal Rank 1.0
# Normalized DCG_k 0.4704
# Accuracy (Project_manager): 2/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Database_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 0, 0, 1, 0]
# Average Precision 0.75
# Modified Average Precision 0.5467
# Reciprocal Rank 1.0
# Normalized DCG_k 0.4852
# Accuracy (Software_Developer): 2/5
#
# relevance_of_indices_retrieved [0, 0, 1, 1, 1]
# Average Precision 0.4778
# Modified Average Precision 0.2867
# Reciprocal Rank 0.3333
# Normalized DCG_k 0.4469
# Accuracy (Front_End_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 1]
# Average Precision 0.95
# Modified Average Precision 0.91
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8539
# Accuracy (Web_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 1]
# Average Precision 0.95
# Modified Average Precision 0.91
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8539
# Accuracy (Java_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 1]
# Average Precision 1.0
# Modified Average Precision 1.0
# Reciprocal Rank 1.0
# Normalized DCG_k 1.0
# Accuracy (Network_Administrator): 5/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Python_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Security_Analyst): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Systems_Administrator): 4/5
#
# relevance_of_indices_retrieved [1, 0, 0, 1, 0]
# Average Precision 0.75
# Modified Average Precision 0.5467
# Reciprocal Rank 1.0
# Normalized DCG_k 0.4852
# Accuracy (Project_manager): 2/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Database_Administrator): 4/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 0]
# Average Precision 0.9167
# Modified Average Precision 0.8033
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6992
# Accuracy (Software_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 1]
# Average Precision 0.8667
# Modified Average Precision 0.7533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6844
# Accuracy (Front_End_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Web_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 0, 1, 1, 1]
# Average Precision 0.8042
# Modified Average Precision 0.7433
# Reciprocal Rank 1.0
# Normalized DCG_k 0.786
# Accuracy (Java_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Network_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.7133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5531
# Accuracy (Python_Developer): 2/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 1]
# Average Precision 0.95
# Modified Average Precision 0.91
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8539
# Accuracy (Security_Analyst): 4/5
#
# relevance_of_indices_retrieved [0, 1, 1, 0, 1]
# Average Precision 0.5889
# Modified Average Precision 0.4533
# Reciprocal Rank 0.5
# Normalized DCG_k 0.5148
# Accuracy (Systems_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 0, 1, 0, 1]
# Average Precision 0.7556
# Modified Average Precision 0.6533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6399
# Accuracy (Project_manager): 3/5
#
# relevance_of_indices_retrieved [1, 0, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.4567
# Reciprocal Rank 1.0
# Normalized DCG_k 0.3392
# Accuracy (Database_Administrator): 1/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 1]
# Average Precision 0.95
# Modified Average Precision 0.91
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8539
# Accuracy (Software_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 0, 1, 1, 0]
# Average Precision 0.8056
# Modified Average Precision 0.7033
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6548
# Accuracy (Front_End_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Web_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 0, 1, 0, 1]
# Average Precision 0.7556
# Modified Average Precision 0.6533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6399
# Accuracy (Java_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 1]
# Average Precision 1.0
# Modified Average Precision 1.0
# Reciprocal Rank 1.0
# Normalized DCG_k 1.0
# Accuracy (Network_Administrator): 5/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Python_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 0, 1, 0, 0]
# Average Precision 0.8333
# Modified Average Precision 0.6133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5087
# Accuracy (Security_Analyst): 2/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 1]
# Average Precision 1.0
# Modified Average Precision 1.0
# Reciprocal Rank 1.0
# Normalized DCG_k 1.0
# Accuracy (Systems_Administrator): 5/5
#
# relevance_of_indices_retrieved [1, 0, 1, 0, 0]
# Average Precision 0.8333
# Modified Average Precision 0.6133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5087
# Accuracy (Project_manager): 2/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 0]
# Average Precision 0.9167
# Modified Average Precision 0.8033
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6992
# Accuracy (Database_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.7133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5531
# Accuracy (Software_Developer): 2/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Front_End_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 1]
# Average Precision 0.95
# Modified Average Precision 0.91
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8539
# Accuracy (Web_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 0, 1, 1, 1]
# Average Precision 0.8042
# Modified Average Precision 0.7433
# Reciprocal Rank 1.0
# Normalized DCG_k 0.786
# Accuracy (Java_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 1]
# Average Precision 0.95
# Modified Average Precision 0.91
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8539
# Accuracy (Network_Administrator): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 1]
# Average Precision 1.0
# Modified Average Precision 1.0
# Reciprocal Rank 1.0
# Normalized DCG_k 1.0
# Accuracy (Python_Developer): 5/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 1]
# Average Precision 0.8667
# Modified Average Precision 0.7533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6844
# Accuracy (Security_Analyst): 3/5
#
# relevance_of_indices_retrieved [1, 0, 1, 0, 0]
# Average Precision 0.8333
# Modified Average Precision 0.6133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5087
# Accuracy (Systems_Administrator): 2/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.7133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5531
# Accuracy (Project_manager): 2/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Database_Administrator): 4/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.7133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5531
# Accuracy (Software_Developer): 2/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 1]
# Average Precision 0.95
# Modified Average Precision 0.91
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8539
# Accuracy (Front_End_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 0, 0, 1, 0]
# Average Precision 0.75
# Modified Average Precision 0.5467
# Reciprocal Rank 1.0
# Normalized DCG_k 0.4852
# Accuracy (Web_Developer): 2/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 0]
# Average Precision 0.9167
# Modified Average Precision 0.8033
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6992
# Accuracy (Java_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 1]
# Average Precision 0.95
# Modified Average Precision 0.91
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8539
# Accuracy (Network_Administrator): 4/5
#
# relevance_of_indices_retrieved [1, 0, 1, 0, 0]
# Average Precision 0.8333
# Modified Average Precision 0.6133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5087
# Accuracy (Python_Developer): 2/5
#
# Mean Average Precision: 0.8966
# Modified Mean Average Precision: 0.7812
# Mean Reciprocal Rank: 0.9683
# Mean Normalized DGC_k: 0.7147
# Total accuracy: 325/500

# %% [markdown]
# #### 5.4 BM25 + DPR FT2(BATCH SIZE 16)

# %% [markdown]
# ##### 5.4.1 INITIALIZATIONS

# %%
lambda_val = 1.1
question_encoder = DPRQuestionEncoder.from_pretrained(
    "./models_16/finetune_question_encoder"
).to(device)
context_encoder = DPRContextEncoder.from_pretrained(
    "./models_16/finetune_context_encoder"
).to(device)

correct_predictions = 0
positve_samples = 0
accuracy_list = []

total_average_precision = 0
total_modified_average_precision = 0
total_reciprocal_rank = 0
total_normalized_DCG_k = 0

# %% [markdown]
# ##### 5.4.2 CALCULATE METRICS

# %%
for sample in test_data:
    label = sample["label"]
    job_description = sample["description"]
    pos_samples = sample["pos"]
    neg_samples = sample["neg"]
    all_samples = pos_samples + neg_samples
    # random.shuffle(all_samples)

    question_output = encode(question_tokenizer, question_encoder, job_description)
    context_output = encode(context_tokenizer, context_encoder, all_samples)
    scores = F.cosine_similarity(question_output, context_output).detach().cpu().numpy()
    scores = scores/np.max(scores)

    tokenized_all = [doc.split(" ") for doc in all_samples]
    bm25 = BM25Okapi(tokenized_all)

    tokenized_query = job_description.split(" ")
    scores_bm25 = bm25.get_scores(tokenized_query)
    scores_bm25=scores_bm25/np.max(scores_bm25)
    # from IPython import embed; embed()
    # print(scores_bm25)

    consolidated_scores = torch.from_numpy(lambda_val*scores + scores_bm25)
    _, indices = torch.topk(consolidated_scores, 5)

    # print('indices',indices)
    relevance_of_indices_retrieved = []

    relevant_passages = np.array(all_samples)[indices.numpy()]
    num_correct = 0
    for p in relevant_passages:
        if p in pos_samples:
            num_correct += 1
            relevance_of_indices_retrieved.append(1)
        else:
            relevance_of_indices_retrieved.append(0)

    correct_predictions += num_correct
    positve_samples += 5

    average_precision = calculate_average_precision(relevance_of_indices_retrieved)
    modified_average_precision = calculate_modified_average_precision(relevance_of_indices_retrieved)
    reciprocal_rank = calculate_reciprocal_rank(relevance_of_indices_retrieved)
    normalized_DCG_k = calculate_normalized_DCG_k(relevance_of_indices_retrieved, len(relevance_of_indices_retrieved))
    total_average_precision += average_precision
    total_modified_average_precision += modified_average_precision
    total_reciprocal_rank += reciprocal_rank
    total_normalized_DCG_k += normalized_DCG_k

    accuracy_list.append(num_correct)
    print('relevance_of_indices_retrieved',relevance_of_indices_retrieved) 
    print('Average Precision',round(average_precision, 4))
    print('Modified Average Precision', round(modified_average_precision, 4))
    print('Reciprocal Rank', round(reciprocal_rank, 4))
    print('Normalized DCG_k', round(normalized_DCG_k, 4))
    print(f"Accuracy ({label}): {num_correct}/{len(relevant_passages)}")
    print()


accuracy_list.append(correct_predictions)
comparison_data["BM25 + DPR FT2(16)"] = accuracy_list

total_average_precision = round(total_average_precision, 2)
total_modified_average_precision = round(total_modified_average_precision, 2)
total_reciprocal_rank = round(total_reciprocal_rank, 2)
total_normalized_DCG_k = round(total_normalized_DCG_k, 2)

print(f"Mean Average Precision: {round(total_average_precision/len(test_data), 4)}")
print(f"Modified Mean Average Precision: {round(total_modified_average_precision/len(test_data), 4)}")
print(f"Mean Reciprocal Rank: {round(total_reciprocal_rank/len(test_data), 4)}")
print(f"Mean Normalized DCG_k: {round(total_normalized_DCG_k/len(test_data), 4)}")
print(f"Total accuracy: {correct_predictions}/{positve_samples}")
# Out:
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Security_Analyst): 3/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 0]
# Average Precision 0.9167
# Modified Average Precision 0.8033
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6992
# Accuracy (Systems_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 0]
# Average Precision 0.9167
# Modified Average Precision 0.8033
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6992
# Accuracy (Project_manager): 3/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 1]
# Average Precision 0.8667
# Modified Average Precision 0.7533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6844
# Accuracy (Database_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Software_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 0, 1, 0, 0]
# Average Precision 0.8333
# Modified Average Precision 0.6133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5087
# Accuracy (Front_End_Developer): 2/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Web_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Java_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 0, 1, 1, 1]
# Average Precision 0.8042
# Modified Average Precision 0.7433
# Reciprocal Rank 1.0
# Normalized DCG_k 0.786
# Accuracy (Network_Administrator): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Python_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Security_Analyst): 3/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.7133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5531
# Accuracy (Systems_Administrator): 2/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Project_manager): 4/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 1]
# Average Precision 0.8667
# Modified Average Precision 0.7533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6844
# Accuracy (Database_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 1]
# Average Precision 1.0
# Modified Average Precision 1.0
# Reciprocal Rank 1.0
# Normalized DCG_k 1.0
# Accuracy (Software_Developer): 5/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Front_End_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 1]
# Average Precision 0.8667
# Modified Average Precision 0.7533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6844
# Accuracy (Web_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 1]
# Average Precision 0.95
# Modified Average Precision 0.91
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8539
# Accuracy (Java_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Network_Administrator): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 1]
# Average Precision 1.0
# Modified Average Precision 1.0
# Reciprocal Rank 1.0
# Normalized DCG_k 1.0
# Accuracy (Python_Developer): 5/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Security_Analyst): 3/5
#
# relevance_of_indices_retrieved [1, 0, 1, 0, 0]
# Average Precision 0.8333
# Modified Average Precision 0.6133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5087
# Accuracy (Systems_Administrator): 2/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 1]
# Average Precision 0.8875
# Modified Average Precision 0.8433
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8304
# Accuracy (Project_manager): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Database_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 1]
# Average Precision 1.0
# Modified Average Precision 1.0
# Reciprocal Rank 1.0
# Normalized DCG_k 1.0
# Accuracy (Software_Developer): 5/5
#
# relevance_of_indices_retrieved [1, 0, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.4567
# Reciprocal Rank 1.0
# Normalized DCG_k 0.3392
# Accuracy (Front_End_Developer): 1/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Web_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 1]
# Average Precision 1.0
# Modified Average Precision 1.0
# Reciprocal Rank 1.0
# Normalized DCG_k 1.0
# Accuracy (Java_Developer): 5/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 1]
# Average Precision 0.95
# Modified Average Precision 0.91
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8539
# Accuracy (Network_Administrator): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Python_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Security_Analyst): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Systems_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Project_manager): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Database_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 1]
# Average Precision 1.0
# Modified Average Precision 1.0
# Reciprocal Rank 1.0
# Normalized DCG_k 1.0
# Accuracy (Software_Developer): 5/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Front_End_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 0, 1, 0, 1]
# Average Precision 0.7556
# Modified Average Precision 0.6533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6399
# Accuracy (Web_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Java_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Network_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Python_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Security_Analyst): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 1]
# Average Precision 0.95
# Modified Average Precision 0.91
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8539
# Accuracy (Systems_Administrator): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Project_manager): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Database_Administrator): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Software_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Front_End_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 0]
# Average Precision 0.9167
# Modified Average Precision 0.8033
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6992
# Accuracy (Web_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 1]
# Average Precision 0.95
# Modified Average Precision 0.91
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8539
# Accuracy (Java_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 1]
# Average Precision 0.95
# Modified Average Precision 0.91
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8539
# Accuracy (Network_Administrator): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Python_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Security_Analyst): 3/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 0]
# Average Precision 0.9167
# Modified Average Precision 0.8033
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6992
# Accuracy (Systems_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 1]
# Average Precision 0.95
# Modified Average Precision 0.91
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8539
# Accuracy (Project_manager): 4/5
#
# relevance_of_indices_retrieved [1, 0, 0, 0, 1]
# Average Precision 0.7
# Modified Average Precision 0.4967
# Reciprocal Rank 1.0
# Normalized DCG_k 0.4704
# Accuracy (Database_Administrator): 2/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Software_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 1]
# Average Precision 0.8875
# Modified Average Precision 0.8433
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8304
# Accuracy (Front_End_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 0]
# Average Precision 0.9167
# Modified Average Precision 0.8033
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6992
# Accuracy (Web_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Java_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 1]
# Average Precision 1.0
# Modified Average Precision 1.0
# Reciprocal Rank 1.0
# Normalized DCG_k 1.0
# Accuracy (Network_Administrator): 5/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 1]
# Average Precision 0.8667
# Modified Average Precision 0.7533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6844
# Accuracy (Python_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 1]
# Average Precision 1.0
# Modified Average Precision 1.0
# Reciprocal Rank 1.0
# Normalized DCG_k 1.0
# Accuracy (Security_Analyst): 5/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 1]
# Average Precision 0.95
# Modified Average Precision 0.91
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8539
# Accuracy (Systems_Administrator): 4/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 1]
# Average Precision 0.8667
# Modified Average Precision 0.7533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6844
# Accuracy (Project_manager): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 1]
# Average Precision 1.0
# Modified Average Precision 1.0
# Reciprocal Rank 1.0
# Normalized DCG_k 1.0
# Accuracy (Database_Administrator): 5/5
#
# relevance_of_indices_retrieved [1, 0, 1, 0, 0]
# Average Precision 0.8333
# Modified Average Precision 0.6133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5087
# Accuracy (Software_Developer): 2/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 1]
# Average Precision 0.8875
# Modified Average Precision 0.8433
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8304
# Accuracy (Front_End_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 0]
# Average Precision 0.9167
# Modified Average Precision 0.8033
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6992
# Accuracy (Web_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Java_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Network_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 0, 0, 1, 1]
# Average Precision 0.7
# Modified Average Precision 0.5867
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6164
# Accuracy (Python_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 1]
# Average Precision 0.95
# Modified Average Precision 0.91
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8539
# Accuracy (Security_Analyst): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 1]
# Average Precision 0.95
# Modified Average Precision 0.91
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8539
# Accuracy (Systems_Administrator): 4/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.7133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5531
# Accuracy (Project_manager): 2/5
#
# relevance_of_indices_retrieved [1, 0, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.4567
# Reciprocal Rank 1.0
# Normalized DCG_k 0.3392
# Accuracy (Database_Administrator): 1/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Software_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 0]
# Average Precision 0.9167
# Modified Average Precision 0.8033
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6992
# Accuracy (Front_End_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 1]
# Average Precision 0.8875
# Modified Average Precision 0.8433
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8304
# Accuracy (Web_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 1]
# Average Precision 0.8667
# Modified Average Precision 0.7533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6844
# Accuracy (Java_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 1]
# Average Precision 1.0
# Modified Average Precision 1.0
# Reciprocal Rank 1.0
# Normalized DCG_k 1.0
# Accuracy (Network_Administrator): 5/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Python_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 1]
# Average Precision 0.8875
# Modified Average Precision 0.8433
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8304
# Accuracy (Security_Analyst): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Systems_Administrator): 4/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.7133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5531
# Accuracy (Project_manager): 2/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 1]
# Average Precision 0.8667
# Modified Average Precision 0.7533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6844
# Accuracy (Database_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 1]
# Average Precision 0.95
# Modified Average Precision 0.91
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8539
# Accuracy (Software_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.7133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5531
# Accuracy (Front_End_Developer): 2/5
#
# relevance_of_indices_retrieved [1, 0, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.4567
# Reciprocal Rank 1.0
# Normalized DCG_k 0.3392
# Accuracy (Web_Developer): 1/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Java_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 1]
# Average Precision 0.95
# Modified Average Precision 0.91
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8539
# Accuracy (Network_Administrator): 4/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Python_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 1]
# Average Precision 0.8667
# Modified Average Precision 0.7533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6844
# Accuracy (Security_Analyst): 3/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.7133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5531
# Accuracy (Systems_Administrator): 2/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.7133
# Reciprocal Rank 1.0
# Normalized DCG_k 0.5531
# Accuracy (Project_manager): 2/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 0]
# Average Precision 1.0
# Modified Average Precision 0.87
# Reciprocal Rank 1.0
# Normalized DCG_k 0.7227
# Accuracy (Database_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 0, 1, 1, 1]
# Average Precision 0.8042
# Modified Average Precision 0.7433
# Reciprocal Rank 1.0
# Normalized DCG_k 0.786
# Accuracy (Software_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 0, 1, 0]
# Average Precision 0.9167
# Modified Average Precision 0.8033
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6992
# Accuracy (Front_End_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 1]
# Average Precision 0.8667
# Modified Average Precision 0.7533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6844
# Accuracy (Web_Developer): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 1, 0]
# Average Precision 1.0
# Modified Average Precision 0.96
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8688
# Accuracy (Java_Developer): 4/5
#
# relevance_of_indices_retrieved [1, 1, 0, 0, 1]
# Average Precision 0.8667
# Modified Average Precision 0.7533
# Reciprocal Rank 1.0
# Normalized DCG_k 0.6844
# Accuracy (Network_Administrator): 3/5
#
# relevance_of_indices_retrieved [1, 1, 1, 0, 1]
# Average Precision 0.95
# Modified Average Precision 0.91
# Reciprocal Rank 1.0
# Normalized DCG_k 0.8539
# Accuracy (Python_Developer): 4/5
#
# Mean Average Precision: 0.951
# Modified Mean Average Precision: 0.8454
# Mean Reciprocal Rank: 1.0
# Mean Normalized DCG_k: 0.7611
# Total accuracy: 341/500

# %% [markdown]
# ### 6. RESULTS

# %%
# Intentionally only accuracy results are displayed for comparision. 
# MAP, MRR, MNDCG results of each query of corresponsind can be seen in the output part section 5.
pd.set_option("display.max_rows", None)
comparison_data
# Out:
#                       Label  BM25  DPR Base  DPR FT2(16)  BM25 + DPR FT2(16)
# 0          Security_Analyst     3         2            3                   3
# 1     Systems_Administrator     3         3            3                   3
# 2           Project_manager     2         3            4                   3
# 3    Database_Administrator     2         3            5                   3
# 4        Software_Developer     4         3            4                   4
# 5       Front_End_Developer     2         2            2                   2
# 6             Web_Developer     4         0            1                   3
# 7            Java_Developer     4         3            3                   4
# 8     Network_Administrator     3         3            3                   4
# 9          Python_Developer     4         2            2                   4
# 10         Security_Analyst     3         3            3                   3
# 11    Systems_Administrator     2         3            3                   2
# 12          Project_manager     3         3            3                   4
# 13   Database_Administrator     2         3            4                   3
# 14       Software_Developer     4         3            3                   5
# 15      Front_End_Developer     4         2            4                   4
# 16            Web_Developer     2         3            3                   3
# 17           Java_Developer     4         1            2                   4
# 18    Network_Administrator     4         3            2                   4
# 19         Python_Developer     4         2            4                   5
# 20         Security_Analyst     3         3            4                   3
# 21    Systems_Administrator     2         1            2                   2
# 22          Project_manager     4         2            3                   4
# 23   Database_Administrator     3         3            2                   3
# 24       Software_Developer     5         3            4                   5
# 25      Front_End_Developer     1         1            2                   1
# 26            Web_Developer     3         2            3                   3
# 27           Java_Developer     5         2            3                   5
# 28    Network_Administrator     3         3            4                   4
# 29         Python_Developer     4         2            4                   4
# 30         Security_Analyst     4         5            5                   4
# 31    Systems_Administrator     3         5            3                   3
# 32          Project_manager     3         3            4                   3
# 33   Database_Administrator     3         4            4                   3
# 34       Software_Developer     4         2            4                   5
# 35      Front_End_Developer     3         1            3                   3
# 36            Web_Developer     3         1            2                   3
# 37           Java_Developer     4         0            4                   3
# 38    Network_Administrator     3         3            4                   3
# 39         Python_Developer     3         3            4                   3
# 40         Security_Analyst     4         3            2                   4
# 41    Systems_Administrator     3         3            4                   4
# 42          Project_manager     3         3            3                   3
# 43   Database_Administrator     3         3            3                   4
# 44       Software_Developer     3         2            4                   3
# 45      Front_End_Developer     4         2            3                   4
# 46            Web_Developer     3         2            3                   3
# 47           Java_Developer     4         0            3                   4
# 48    Network_Administrator     3         4            5                   4
# 49         Python_Developer     4         4            4                   4
# 50         Security_Analyst     2         2            3                   3
# 51    Systems_Administrator     3         4            4                   3
# 52          Project_manager     4         1            2                   4
# 53   Database_Administrator     2         2            3                   2
# 54       Software_Developer     3         1            2                   3
# 55      Front_End_Developer     4         1            3                   4
# 56            Web_Developer     2         3            4                   3
# 57           Java_Developer     4         3            4                   4
# 58    Network_Administrator     5         4            5                   5
# 59         Python_Developer     2         4            4                   3
# 60         Security_Analyst     5         4            4                   5
# 61    Systems_Administrator     4         3            4                   4
# 62          Project_manager     3         2            2                   3
# 63   Database_Administrator     4         3            4                   5
# 64       Software_Developer     2         1            3                   2
# 65      Front_End_Developer     3         2            3                   4
# 66            Web_Developer     2         2            3                   3
# 67           Java_Developer     4         1            4                   4
# 68    Network_Administrator     2         3            3                   3
# 69         Python_Developer     2         2            2                   3
# 70         Security_Analyst     4         5            4                   4
# 71    Systems_Administrator     4         2            3                   4
# 72          Project_manager     2         2            3                   2
# 73   Database_Administrator     1         1            1                   1
# 74       Software_Developer     4         1            4                   4
# 75      Front_End_Developer     3         1            3                   3
# 76            Web_Developer     4         1            3                   4
# 77           Java_Developer     3         3            3                   3
# 78    Network_Administrator     4         5            5                   5
# 79         Python_Developer     3         3            4                   4
# 80         Security_Analyst     3         2            2                   4
# 81    Systems_Administrator     3         3            5                   4
# 82          Project_manager     2         3            2                   2
# 83   Database_Administrator     2         3            3                   3
# 84       Software_Developer     4         1            2                   4
# 85      Front_End_Developer     2         0            4                   2
# 86            Web_Developer     1         3            4                   1
# 87           Java_Developer     4         1            4                   4
# 88    Network_Administrator     3         3            4                   4
# 89         Python_Developer     4         3            5                   4
# 90         Security_Analyst     4         4            3                   3
# 91    Systems_Administrator     3         2            2                   2
# 92          Project_manager     1         3            2                   2
# 93   Database_Administrator     3         2            4                   3
# 94       Software_Developer     4         2            2                   4
# 95      Front_End_Developer     3         3            4                   3
# 96            Web_Developer     3         1            2                   3
# 97           Java_Developer     4         1            3                   4
# 98    Network_Administrator     1         4            4                   3
# 99         Python_Developer     4         2            2                   4
# 100                   Total   315       243          325                 341
